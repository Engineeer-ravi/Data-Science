# %% [markdown]
# ## Class reletionship

# %% [markdown]
# # . Agregetion
# # . Inheritence

# %%
# eaxample
class Customer:
     def __init__(self,name,gender,address):
         self.name = name
         self.gender = gender
         self.address= address

     def print_address(self):
         print(self.address.city,self.address.pin,self.address.state)

class Address:
     def __init__(self,city,pin,state):
         self.city = city
         self.pin = pin
         self.state= state
add1= Address('gurugaon',12001,'harayana')
cust= Customer('ravi','male')

cust.print_address()
# method
# what aboyr private attribute
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      15          self.state= state
#      16 add1= Address('gurugaon',12001,'harayana')
# ---> 17 cust= Customer('ravi','male')
#      19 cust.print_address()
#
# TypeError: Customer.__init__() missing 1 required positional argument: 'address'
